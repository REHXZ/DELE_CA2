# %%
# !pip install gym==0.17.3
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.6 MB 640.0 kB/s eta 0:00:03
#      ------------- -------------------------- 0.5/1.6 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scipy (from gym==0.17.3)
#   Downloading scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# Collecting numpy>=1.10.4 (from gym==0.17.3)
#   Downloading numpy-2.0.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB ? eta 0:00:00
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym==0.17.3)
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.17.3)
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting future (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading numpy-2.0.0-cp312-cp312-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    --------- ------------------------------ 3.7/16.2 MB 77.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.1/16.2 MB 98.0 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/16.2 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 93.0 MB/s eta 0:00:00
# Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB ? eta 0:00:00
# Downloading scipy-1.14.0-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---- ----------------------------------- 4.6/44.5 MB 147.0 MB/s eta 0:00:01
#    --------- ------------------------------ 10.1/44.5 MB 129.7 MB/s eta 0:00:01
#    -------------- ------------------------- 15.6/44.5 MB 131.2 MB/s eta 0:00:01
#    ------------------- -------------------- 21.1/44.5 MB 110.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 24.9/44.5 MB 93.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.4/44.5 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 37.9/44.5 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  43.5/44.5 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 73.0 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    ---------------------------------------- 491.3/491.3 kB ? eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654629 sha256=3db951e260d7bc6feb1930813bb405030e8e1aaab23780465111d857a821b0f6
#   Stored in directory: c:\users\p2348935\appdata\local\pip\cache\wheels\99\7e\03\69cdeb432380e05bc9a56ff68451d8063e41aa06db508f4be5
# Successfully built gym
# Installing collected packages: numpy, future, cloudpickle, scipy, pyglet, gym
# Successfully installed cloudpickle-1.6.0 future-1.0.0 gym-0.17.3 numpy-2.0.0 pyglet-1.5.0 scipy-1.14.0
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      --------- ----------------------------- 41.0/165.9 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 5.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/8.0 MB 26.1 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 34.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 52.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 51.1 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    ---------------------------------------- 189.9/189.9 kB ? eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 136.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 82.1 MB/s eta 0:00:00
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting tensorflow-intel==2.17.0 (from tensorflow)
#   Downloading tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading h5py-3.11.0-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading ml_dtypes-0.4.0-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading grpcio-1.64.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.2.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB ? eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Collecting rich (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading optree-0.12.1-cp312-cp312-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 48.7/48.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.7.4)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\p2348935\.conda\envs\rl\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Downloading tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl (385.2 MB)
#    ---------------------------------------- 0.0/385.2 MB ? eta -:--:--
#    ---------------------------------------- 1.4/385.2 MB 30.5 MB/s eta 0:00:13
#    ---------------------------------------- 3.9/385.2 MB 41.4 MB/s eta 0:00:10
#     --------------------------------------- 8.6/385.2 MB 61.1 MB/s eta 0:00:07
#    - -------------------------------------- 12.9/385.2 MB 93.0 MB/s eta 0:00:05
#    - ------------------------------------- 18.6/385.2 MB 108.8 MB/s eta 0:00:04
#    -- ------------------------------------- 21.0/385.2 MB 93.9 MB/s eta 0:00:04
#    -- ------------------------------------- 22.2/385.2 MB 65.6 MB/s eta 0:00:06
#    -- ------------------------------------- 27.9/385.2 MB 73.1 MB/s eta 0:00:05
#    --- ----------------------------------- 31.5/385.2 MB 129.5 MB/s eta 0:00:03
#    --- ------------------------------------ 32.1/385.2 MB 72.6 MB/s eta 0:00:05
#    --- ------------------------------------ 36.4/385.2 MB 65.6 MB/s eta 0:00:06
#    ---- ---------------------------------- 42.0/385.2 MB 108.8 MB/s eta 0:00:04
#    ---- ---------------------------------- 47.6/385.2 MB 162.4 MB/s eta 0:00:03
#    ----- --------------------------------- 53.3/385.2 MB 129.5 MB/s eta 0:00:03
#    ----- --------------------------------- 58.8/385.2 MB 131.2 MB/s eta 0:00:03
#    ------ -------------------------------- 64.2/385.2 MB 131.2 MB/s eta 0:00:03
#    ------- ------------------------------- 69.9/385.2 MB 131.2 MB/s eta 0:00:03
#    ------- ------------------------------- 75.4/385.2 MB 131.2 MB/s eta 0:00:03
#    -------- ------------------------------ 80.8/385.2 MB 131.2 MB/s eta 0:00:03
#    -------- ------------------------------ 86.4/385.2 MB 131.2 MB/s eta 0:00:03
#    --------- ----------------------------- 89.1/385.2 MB 108.8 MB/s eta 0:00:03
#    --------- ------------------------------ 91.9/385.2 MB 81.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 97.3/385.2 MB 81.8 MB/s eta 0:00:04
#    ---------- --------------------------- 103.1/385.2 MB 108.8 MB/s eta 0:00:03
#    ---------- --------------------------- 108.2/385.2 MB 108.8 MB/s eta 0:00:03
#    ----------- -------------------------- 113.8/385.2 MB 131.2 MB/s eta 0:00:03
#    ----------- -------------------------- 119.5/385.2 MB 131.2 MB/s eta 0:00:03
#    ------------ ------------------------- 125.1/385.2 MB 131.2 MB/s eta 0:00:02
#    ------------ ------------------------- 130.8/385.2 MB 110.0 MB/s eta 0:00:03
#    ------------- ------------------------ 136.3/385.2 MB 108.8 MB/s eta 0:00:03
#    ------------- ------------------------ 141.6/385.2 MB 108.8 MB/s eta 0:00:03
#    -------------- ----------------------- 147.2/385.2 MB 108.8 MB/s eta 0:00:03
#    --------------- ---------------------- 152.8/385.2 MB 108.8 MB/s eta 0:00:03
#    --------------- ---------------------- 158.1/385.2 MB 108.8 MB/s eta 0:00:03
#    ---------------- --------------------- 163.6/385.2 MB 108.8 MB/s eta 0:00:03
#    ---------------- --------------------- 169.3/385.2 MB 110.0 MB/s eta 0:00:02
#    ----------------- -------------------- 174.9/385.2 MB 131.2 MB/s eta 0:00:02
#    ----------------- -------------------- 179.6/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------ ------------------- 185.5/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------ ------------------- 191.4/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------- ------------------ 196.9/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------- ------------------ 202.6/385.2 MB 108.8 MB/s eta 0:00:02
#    -------------------- ----------------- 208.1/385.2 MB 129.5 MB/s eta 0:00:02
#    -------------------- ----------------- 209.7/385.2 MB 108.8 MB/s eta 0:00:02
#    -------------------- ----------------- 209.7/385.2 MB 108.8 MB/s eta 0:00:02
#    --------------------- ----------------- 212.4/385.2 MB 54.7 MB/s eta 0:00:04
#    ---------------------- ---------------- 217.5/385.2 MB 54.7 MB/s eta 0:00:04
#    --------------------- ---------------- 220.2/385.2 MB 131.2 MB/s eta 0:00:02
#    ---------------------- ---------------- 224.7/385.2 MB 81.8 MB/s eta 0:00:02
#    ----------------------- --------------- 230.0/385.2 MB 81.8 MB/s eta 0:00:02
#    ----------------------- -------------- 235.6/385.2 MB 129.5 MB/s eta 0:00:02
#    ----------------------- -------------- 241.3/385.2 MB 131.2 MB/s eta 0:00:02
#    ------------------------ ------------- 246.9/385.2 MB 131.2 MB/s eta 0:00:02
#    ------------------------ ------------- 252.1/385.2 MB 131.2 MB/s eta 0:00:02
#    ------------------------- ------------ 253.7/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------------- ------------ 253.7/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------------- ------------ 253.7/385.2 MB 108.8 MB/s eta 0:00:02
#    ------------------------- ------------ 253.7/385.2 MB 108.8 MB/s eta 0:00:02
#    -------------------------- ------------ 257.7/385.2 MB 36.3 MB/s eta 0:00:04
#    -------------------------- ------------ 263.3/385.2 MB 38.6 MB/s eta 0:00:04
#    -------------------------- ----------- 268.7/385.2 MB 110.0 MB/s eta 0:00:02
#    --------------------------- ---------- 274.5/385.2 MB 131.2 MB/s eta 0:00:01
#    --------------------------- ---------- 280.0/385.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------- --------- 285.5/385.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------- --------- 291.4/385.2 MB 131.2 MB/s eta 0:00:01
#    ----------------------------- -------- 296.5/385.2 MB 108.8 MB/s eta 0:00:01
#    ----------------------------- -------- 302.3/385.2 MB 108.8 MB/s eta 0:00:01
#    ------------------------------ ------- 307.7/385.2 MB 131.2 MB/s eta 0:00:01
#    ------------------------------ ------- 313.4/385.2 MB 131.2 MB/s eta 0:00:01
#    ------------------------------- ------ 319.5/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------- ----- 325.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------- ----- 330.6/385.2 MB 131.2 MB/s eta 0:00:01
#    --------------------------------- ---- 336.5/385.2 MB 131.2 MB/s eta 0:00:01
#    --------------------------------- ---- 340.8/385.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------- --- 345.7/385.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------- --- 351.7/385.2 MB 131.2 MB/s eta 0:00:01
#    ----------------------------------- -- 357.1/385.2 MB 131.2 MB/s eta 0:00:01
#    ----------------------------------- -- 362.6/385.2 MB 131.2 MB/s eta 0:00:01
#    ------------------------------------ - 367.7/385.2 MB 131.2 MB/s eta 0:00:01
#    ------------------------------------ - 373.4/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  379.7/385.2 MB 162.4 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    -------------------------------------  385.1/385.2 MB 131.2 MB/s eta 0:00:01
#    --------------------------------------- 385.2/385.2 MB 18.2 MB/s eta 0:00:00
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.64.1-cp312-cp312-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------  4.1/4.1 MB 131.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 86.6 MB/s eta 0:00:00
# Downloading h5py-3.11.0-cp312-cp312-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 92.5 MB/s eta 0:00:00
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 70.1 MB/s eta 0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading ml_dtypes-0.4.0-cp312-cp312-win_amd64.whl (127 kB)
#    ---------------------------------------- 0.0/127.5 kB ? eta -:--:--
#    ---------------------------------------- 127.5/127.5 kB 7.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    --------------- ------------------------ 6.1/15.5 MB 129.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.5 MB 129.5 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 93.8 MB/s eta 0:00:00
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------------------------- -------- 4.4/5.5 MB 140.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 88.6 MB/s eta 0:00:00
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    --------------------------------------- 227.3/227.3 kB 13.6 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp312-cp312-win_amd64.whl (267 kB)
#    ---------------------------------------- 0.0/267.2 kB ? eta -:--:--
#    --------------------------------------- 267.2/267.2 kB 16.1 MB/s eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    --------------------------------------- 240.7/240.7 kB 15.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, numpy, mdurl, markdown, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, opt-einsum, ml-dtypes, markdown-it-py, h5py, rich, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.64.1 h5py-3.11.0 keras-3.4.1 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.0 namex-0.0.8 numpy-1.26.4 opt-einsum-3.3.0 optree-0.12.1 protobuf-4.25.3 rich-13.7.1 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-intel-2.17.0 termcolor-2.4.0 werkzeug-3.0.3 wrapt-1.16.0

# %%
import random
import gym
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
EPOCHS = 500
THRESHOLD = 45

# %%
class DQN():
    def __init__(self, env_string,batch_size=64):
        self.memory = deque(maxlen=100000)
        self.env = gym.make(env_string)
        input_size = self.env.observation_space.shape[0]
        action_size = self.env.action_space.n
        self.batch_size = batch_size
        self.gamma = 1.0
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        
        alpha=0.01
        alpha_decay=0.01
        
        # Init model
        self.model = Sequential()
        self.model.add(Dense(24, input_dim=input_size, activation='tanh'))
        self.model.add(Dense(48, activation='tanh'))
        self.model.add(Dense(action_size, activation='linear'))
        self.model.compile(loss='mse', optimizer=Adam(learning_rate=alpha))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def choose_action(self, state, epsilon):
        if np.random.random() <= epsilon:
            return self.env.action_space.sample()
        else:
            return np.argmax(self.model.predict(state, verbose=0))

    def preprocess_state(self, state):
        return np.reshape(state, [1, 4])

    def replay(self, batch_size):
        x_batch, y_batch = [], []
        minibatch = random.sample(self.memory, min(len(self.memory), batch_size))
        for state, action, reward, next_state, done in minibatch:
            y_target = self.model.predict(state, verbose=0)
            y_target[0][action] = reward if done else reward + self.gamma * np.max(self.model.predict(next_state, verbose=0)[0])
            x_batch.append(state[0])
            y_batch.append(y_target[0])
        
        self.model.fit(np.array(x_batch), np.array(y_batch), batch_size=len(x_batch), verbose=0)
        #epsilon = max(epsilon_min, epsilon_decay*epsilon) # decrease epsilon
       

    def train(self):
        scores = deque(maxlen=100)
        avg_scores = []
        

        for e in range(EPOCHS):
            state = self.env.reset()
            if e % 10 == 0:
                self.env.render()
            state = self.preprocess_state(state)
            done = False
            i = 0
            while not done:
                action = self.choose_action(state,self.epsilon)
                next_state, reward, done, _ = self.env.step(action)
                if e % 10 == 0:
                    self.env.render()
                next_state = self.preprocess_state(next_state)
                self.remember(state, action, reward, next_state, done)
                state = next_state
                self.epsilon = max(self.epsilon_min, self.epsilon_decay*self.epsilon) # decrease epsilon
                i += 1
                
            if e % 10 == 0:
                self.env.close()

            scores.append(i)
            mean_score = np.mean(scores)
            avg_scores.append(mean_score)
            print(f'Epoch number {e}')
            if mean_score >= THRESHOLD and e >= 10:
                print('Ran {} episodes. Solved after {} trials ✔'.format(e, e - 10))
                return avg_scores
            if e % 10 == 0:
                print('[Episode {}] - Mean survival time over last 10 episodes was {} ticks.'.format(e, mean_score))

            self.replay(self.batch_size)
        
        print('Did not solve after {} episodes 😞'.format(e))
        return avg_scores

# %%
env_string = 'CartPole-v0'
agent = DQN(env_string)
scores = agent.train()
# Out:
# C:\Users\p2348935\.conda\envs\RL\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch number 0
# [Episode 0] - Mean survival time over last 10 episodes was 14.0 ticks.
# Epoch number 1
# Epoch number 2
# Epoch number 3
# Epoch number 4
# Epoch number 5
# Epoch number 6
# Epoch number 7
# Epoch number 8
# Epoch number 9
# Epoch number 10
# [Episode 10] - Mean survival time over last 10 episodes was 14.181818181818182 ticks.
# Epoch number 11
# Epoch number 12
# Epoch number 13
# Epoch number 14
# Epoch number 15
# Epoch number 16
# Epoch number 17
# Epoch number 18
# Epoch number 19
# Epoch number 20
# [Episode 20] - Mean survival time over last 10 episodes was 12.904761904761905 ticks.
# Epoch number 21
# Epoch number 22
# Epoch number 23
# Epoch number 24
# Epoch number 25
# Epoch number 26
# Epoch number 27
# Epoch number 28
# Epoch number 29
# Epoch number 30
# [Episode 30] - Mean survival time over last 10 episodes was 15.419354838709678 ticks.
# Epoch number 31
# Epoch number 32
# Epoch number 33
# Epoch number 34
# Epoch number 35
# Epoch number 36
# Epoch number 37
# Epoch number 38
# Epoch number 39
# Epoch number 40
# [Episode 40] - Mean survival time over last 10 episodes was 15.0 ticks.
# Epoch number 41
# Epoch number 42
# Epoch number 43
# Epoch number 44
# Epoch number 45
# Epoch number 46
# Epoch number 47
# Epoch number 48
# Epoch number 49
# Epoch number 50
# [Episode 50] - Mean survival time over last 10 episodes was 15.196078431372548 ticks.
# Epoch number 51
# Epoch number 52
# Epoch number 53
# Epoch number 54
# Epoch number 55
# Epoch number 56
# Epoch number 57
# Epoch number 58
# Epoch number 59
# Epoch number 60
# [Episode 60] - Mean survival time over last 10 episodes was 17.049180327868854 ticks.
# Epoch number 61
# Epoch number 62
# Epoch number 63
# Epoch number 64
# Epoch number 65
# Epoch number 66
# Epoch number 67
# Epoch number 68
# Epoch number 69
# Epoch number 70
# [Episode 70] - Mean survival time over last 10 episodes was 17.633802816901408 ticks.
# Epoch number 71
# Epoch number 72
# Epoch number 73
# Epoch number 74
# Epoch number 75
# Epoch number 76
# Epoch number 77
# Epoch number 78
# Epoch number 79
# Epoch number 80
# [Episode 80] - Mean survival time over last 10 episodes was 17.234567901234566 ticks.
# Epoch number 81
# Epoch number 82
# Epoch number 83
# Epoch number 84
# Epoch number 85
# Epoch number 86
# Epoch number 87
# Epoch number 88
# Epoch number 89
# Epoch number 90
# [Episode 90] - Mean survival time over last 10 episodes was 17.32967032967033 ticks.
# Epoch number 91
# Epoch number 92
# Epoch number 93
# Epoch number 94
# Epoch number 95
# Epoch number 96
# Epoch number 97
# Epoch number 98
# Epoch number 99
# Epoch number 100
# [Episode 100] - Mean survival time over last 10 episodes was 16.99 ticks.
# Epoch number 101
# Epoch number 102
# Epoch number 103
# Epoch number 104
# Epoch number 105
# Epoch number 106
# Epoch number 107
# Epoch number 108
# Epoch number 109
# Epoch number 110
# [Episode 110] - Mean survival time over last 10 episodes was 19.85 ticks.
# Epoch number 111
# Epoch number 112
# Epoch number 113
# Epoch number 114
# Epoch number 115
# Epoch number 116
# Epoch number 117
# Epoch number 118
# Epoch number 119
# Epoch number 120
# [Episode 120] - Mean survival time over last 10 episodes was 22.65 ticks.
# Epoch number 121
# Epoch number 122
# Epoch number 123
# Epoch number 124
# Epoch number 125
# Epoch number 126
# Epoch number 127
# Epoch number 128
# Epoch number 129
# Epoch number 130
# [Episode 130] - Mean survival time over last 10 episodes was 25.34 ticks.
# Epoch number 131
# Epoch number 132
# Epoch number 133
# Epoch number 134
# Epoch number 135
# Epoch number 136
# Epoch number 137
# Epoch number 138
# Epoch number 139
# Epoch number 140
# [Episode 140] - Mean survival time over last 10 episodes was 26.36 ticks.
# Epoch number 141
# Epoch number 142
# Epoch number 143
# Epoch number 144
# Epoch number 145
# Epoch number 146
# Epoch number 147
# Epoch number 148
# Epoch number 149
# Epoch number 150
# [Episode 150] - Mean survival time over last 10 episodes was 27.45 ticks.
# Epoch number 151
# Epoch number 152
# Epoch number 153
# Epoch number 154
# Epoch number 155
# Epoch number 156
# Epoch number 157
# Epoch number 158
# Epoch number 159
# Epoch number 160
# [Episode 160] - Mean survival time over last 10 episodes was 33.21 ticks.
# Epoch number 161
# Epoch number 162
# Epoch number 163
# Epoch number 164
# Epoch number 165
# Epoch number 166
# Epoch number 167
# Epoch number 168
# Epoch number 169
# Epoch number 170
# [Episode 170] - Mean survival time over last 10 episodes was 34.72 ticks.
# Epoch number 171
# Epoch number 172
# Epoch number 173
# Epoch number 174
# Epoch number 175
# Epoch number 176
# Epoch number 177
# Epoch number 178
# Epoch number 179
# Epoch number 180
# [Episode 180] - Mean survival time over last 10 episodes was 43.57 ticks.
# Epoch number 181
# Epoch number 182
# Ran 182 episodes. Solved after 172 trials ✔

# %%
import matplotlib.pyplot as plt
plt.plot(scores)
plt.show()

# %%
agent.model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 24)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 48)             │         1,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            98 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,256 (16.63 KB)
#  Trainable params: 1,418 (5.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,838 (11.09 KB)

# %%
agent.env.close()

# %%
import numpy as np

# Generate 11 evenly spaced values from -2 to 2 (10 intervals means 11 points)
values = np.linspace(-2, 2, 11)

print(values)
# Out:
# [-2.  -1.6 -1.2 -0.8 -0.4  0.   0.4  0.8  1.2  1.6  2. ]
